# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
from google.colab import files 
files = files.upload()
# Out:
#      <input type="file" id="files-6418ed2a-ba14-48ac-8614-15d8954e0bc1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6418ed2a-ba14-48ac-8614-15d8954e0bc1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sorted_final.csv to sorted_final.csv

# %%
import pandas as pd
df = pd.read_csv("sorted_final.csv", index_col = 0)
df
# Out:
#      Station Names  YEAR  ...     Boro_Area  Boro_Production
# 0          Barisal  1970  ...           NaN              NaN
# 1            Bhola  1970  ...           NaN              NaN
# 2            Bogra  1970  ...  3.032000e+04       20574.9558
# 3         Chandpur  1970  ...           NaN              NaN
# 4       Chittagong  1970  ...  1.434810e+05      147662.5025
# ...            ...   ...  ...           ...              ...
# 1521     Srimongal  2018  ...           NaN              NaN
# 1522       Syedpur  2018  ...           NaN              NaN
# 1523        Sylhet  2018  ...  4.269926e+05      241039.0000
# 1524       Tangail  2018  ...  1.025890e+06      840931.0000
# 1525        Teknaf  2018  ...           NaN              NaN
#
# [1561 rows x 15 columns]

# %%
df=df[['YEAR','Max Temp','Min Temp','Rainfall','Relative Humidity','Wind Speed','Cloud Coverage','Bright Sunshine','Aus_Area','Aus_Production']]

# %%
df['YEAR']=pd.to_datetime(df['YEAR'],format ='%Y')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.set_index(df['YEAR'])
# Out:
#                  YEAR   Max Temp  ...       Aus_Area  Aus_Production
# YEAR                              ...
# 1970-01-01 1970-01-01  29.849167  ...            NaN             NaN
# 1970-01-01 1970-01-01  29.835833  ...            NaN             NaN
# 1970-01-01 1970-01-01  30.431667  ...  286080.000000      86400.2994
# 1970-01-01 1970-01-01  29.203333  ...            NaN             NaN
# 1970-01-01 1970-01-01  29.751667  ...  264775.000000     110195.7620
# ...               ...        ...  ...            ...             ...
# 2018-01-01 2018-01-01  30.827500  ...            NaN             NaN
# 2018-01-01 2018-01-01  30.352500  ...            NaN             NaN
# 2018-01-01 2018-01-01  30.565000  ...  286754.109500     157383.0000
# 2018-01-01 2018-01-01  30.771667  ...    7394.472692       1364.0000
# 2018-01-01 2018-01-01  30.683333  ...            NaN             NaN
#
# [1561 rows x 10 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Aus_Production'])
plt.xlabel('YEAR',fontsize =18)
plt.ylabel('Aus_Production',fontsize=18)
plt.show()

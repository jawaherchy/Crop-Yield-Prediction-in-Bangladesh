# %%
import pandas as pd
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-1831afed-aecb-4d1b-975c-3a9323da6ca7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1831afed-aecb-4d1b-975c-3a9323da6ca7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aus_amon_final.csv to aus_amon_final.csv

# %%
df = pd.read_csv('aus_amon_final.csv')
df.dropna(subset = ['Aus_Area', 'Aus_Production', 'Amon_Area','Amon_Production'],axis = 0,inplace = True)
df.drop(['Unnamed: 0'],axis =1 ,inplace = True)
df
# Out:
#      Station Names  YEAR  ...     Amon_Area  Amon_Production
# 2            Bogra  1970  ...  634460.00000    254832.802425
# 4       Chittagong  1970  ...  497290.00000    289460.053875
# 5          Comilla  1970  ...  976420.00000    461126.671425
# 7            Dhaka  1970  ...  765390.00000    283694.893200
# 8         Dinajpur  1970  ...  888530.00000    369283.262025
# ...            ...   ...  ...           ...              ...
# 1551     Rangamati  2016  ...   24596.83170     28235.000000
# 1552       Rangpur  2016  ...  386482.10420    435771.000000
# 1554      Satkhira  2016  ...  230825.72260    282279.000000
# 1558        Sylhet  2016  ...  315849.61100    279939.000000
# 1559       Tangail  2016  ...  313133.92705    277697.000000
#
# [914 rows x 13 columns]

# %%
df = df.sort_values(["YEAR"], ascending=True,ignore_index = True)
df
# Out:
#     Station Names  YEAR  ...     Amon_Area  Amon_Production
# 0           Bogra  1970  ...  6.344600e+05    254832.802425
# 1         Rangpur  1970  ...  1.209490e+06    564291.749625
# 2        Rajshahi  1970  ...  1.111420e+06    493885.121775
# 3      Mymensingh  1970  ...  1.501670e+06    623408.460150
# 4          Khulna  1970  ...  1.007020e+06    397043.123025
# ..            ...   ...  ...           ...              ...
# 909      Rajshahi  2018  ...  4.385881e+05    196177.000000
# 910     Rangamati  2018  ...  6.078000e+04     25136.000000
# 911       Rangpur  2018  ...  9.550166e+05    461649.000000
# 912      Faridpur  2018  ...  3.704014e+05    198852.000000
# 913       Tangail  2018  ...  7.737696e+05    250133.000000
#
# [914 rows x 13 columns]

# %%
df_d=df[df['Station Names'].str.contains("Dhaka")]
df_d.to_csv("new_dhaka.csv")

# %%
df = df.drop(['Station Names'], axis=1)
train=df[:635]
test=df[635:]
print(train,test)
# Out:
#      YEAR   Max Temp   Min Temp  ...  Bright Sunshine  Aus_Area  Aus_Production
# 0    1970  35.758333  20.925000  ...         7.541667    286080    86400.299400
# 1    1970  33.558333  18.891667  ...         6.424762    906800   294821.517225
# 2    1970  32.266667  20.525000  ...         6.820238    474080   157723.184100
# 3    1970  32.941667  20.750000  ...         5.892619   1089970   295456.546725
# 4    1970  34.925000  22.450000  ...         6.618889    119700    44556.391275
# ..    ...        ...        ...  ...              ...       ...             ...
# 630  2007  34.250000  20.375000  ...         6.183333     19260    14343.000000
# 631  2007  33.200000  21.408333  ...         5.683333     34435    25262.000000
# 632  2007  34.100000  21.391667  ...         6.100000     41920    12678.000000
# 633  2007  33.900000  21.783333  ...         5.508333      3490     1239.000000
# 634  2007  33.525000  22.300000  ...         6.591667      1725     1897.000000
#
# ...

# %%
train.to_csv("train.csv")

# %%
test.to_csv("test.csv")

# %%
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 9 to 835
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Station Names      46 non-null     object
#  1   YEAR               46 non-null     int64
#  2   Max Temp           46 non-null     float64
#  3   Min Temp           46 non-null     float64
#  4   Rainfall           46 non-null     float64
#  5   Relative Humidity  46 non-null     float64
#  6   Wind Speed         46 non-null     float64
#  7   Cloud Coverage     46 non-null     float64
#  8   Bright Sunshine    46 non-null     float64
#  9   Aus_Area           46 non-null     int64
#  10  Aus_Production     46 non-null     float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 4.3+ KB

# %%
train_d = df_d[:40]
test_d = df_d[40:]
print(train_d,test_d)
# Out:
#     Station Names  YEAR   Max Temp  ...  Bright Sunshine  Aus_Area  Aus_Production
# 9           Dhaka  1970  33.258333  ...         7.841667    499125   167860.976475
# 20          Dhaka  1971  32.125000  ...         7.025000    400750   131813.980500
# 30          Dhaka  1972  33.783333  ...         7.000000    406315   136336.297725
# 40          Dhaka  1973  33.108333  ...         7.733333    360745    94859.799525
# 62          Dhaka  1974  31.450000  ...         7.791667    385775   125499.972900
# 77          Dhaka  1975  32.975000  ...         8.016667    428705   140082.971775
# 91          Dhaka  1976  33.333333  ...         8.166667    414945   137982.838500
# 104         Dhaka  1977  32.800000  ...         7.250000    406025   139806.280350
# 118         Dhaka  1978  33.791667  ...         6.933333    394620   147812.187975
# 129         Dhaka  1979  33.575000  ...         7.058333    380420   145204.031100
# ...

# %%
train_d.to_csv("train_dhaka.csv")
test_d.to_csv("test_dhaka.csv")

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-8b94446c-7488-4864-b89a-2fca18ebbf58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b94446c-7488-4864-b89a-2fca18ebbf58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sorted year and station names.csv to sorted year and station names.csv

# %%
import pandas as pd
df = pd.read_csv("sorted year and station names.csv", index_col = 0)

# %%
df2 = df.to_excel("sorted year and station names.xlsx")

# %%
df.dropna(axis =0, inplace = True)

# %%
df.dtypes
# Out:
# Unnamed: 0.1           int64
# Station Names         object
# YEAR                   int64
# Max Temp             float64
# Min Temp             float64
# Rainfall             float64
# Relative Humidity    float64
# Wind Speed           float64
# Cloud Coverage       float64
# Bright Sunshine      float64
# Aus_Area             float64
# Aus_Production       float64
# Amon_Area            float64
# Amon_Production      float64
# Boro_Area            float64
# Boro_Production      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1           0
# Station Names          0
# YEAR                   0
# Max Temp               0
# Min Temp               0
# Rainfall               0
# Relative Humidity      1
# Wind Speed             1
# Cloud Coverage         1
# Bright Sunshine        1
# Aus_Area             646
# Aus_Production       646
# Amon_Area            644
# Amon_Production      644
# Boro_Area            647
# Boro_Production      647
# dtype: int64

# %%
avg_temp = df[['Max Temp', 'Min Temp']].mean(axis=1)
avg_temp
# Out:
# 2       28.341667
# 4       26.958333
# 5       27.645833
# 7       27.362500
# 8       27.025000
#           ...
# 1516    25.636667
# 1517    25.206667
# 1519    26.457083
# 1523    25.737083
# 1524    25.805000
# Length: 909, dtype: float64

# %%
df2 = df.assign(AvgTemp=avg_temp)
df2.to_excel("Data.xlsx")

# %%
df3 = df.to_excel("sorted drop nun value.xlsx")
